# %% [markdown]
# ## Utility code

# %%
import pandas as pd
import numpy as np
from datetime import datetime, timedelta
import matplotlib as mpl
import matplotlib.pyplot as plt
import os
import pylab as plt
from os.path import isfile, join
from glob import glob
import subprocess
import re

import geopandas
#from matplotlib_scalebar.scalebar import ScaleBar

import seaborn as sns
sns.set(style="darkgrid")
# Out:
# /Users/swise/opt/anaconda3/envs/covid19_abm/lib/python3.8/site-packages/pyproj/__init__.py:89: UserWarning: pyproj unable to set database path.
#   _pyproj_global_context_initialize()

# %%
def plotMetric(files, prefix, metrics = [], symbol = "-", alpha=1, weighting = 1, label= "", days=30):
    myAvgLine = []
    index = 0
    template = "^" + prefix + "*"

    for f in files:

        if(re.search(template, f) != None): # f.startswith(prefix) and 
            r_data_raw = pd.read_csv(path + f, sep='\t')
            r_data_raw = r_data_raw[r_data_raw['time'] < days]
            
            #we need to add an if statement here for only if it's a multidistrict model do we do this aggregation
            unique_dist_names = pd.unique(r_data_raw['myId'])
            if len(unique_dist_names) == 1:
                r_data = r_data_raw
            else:
                r_data = r_data_raw.groupby('time', as_index=False).agg({'metric_died_count': 'sum', 'metric_new_hospitalized': 'sum', 
                                    'metric_new_critical': 'sum', 'metric_new_cases_asympt': 'sum',
                                    'metric_new_cases_sympt': 'sum', 'metric_new_deaths': 'sum', 
                                    'metric_new_recovered': 'sum', 'metric_currently_infected': 'sum'})
            totcases = []
            for metric in metrics:
                if len(totcases) == 0:
                    totcases = r_data[metric]
                else:        
                    totcases = totcases + r_data[metric]
            #totcases = r_data[metric]
            
            if len(myAvgLine) == 0:
                myAvgLine = totcases
            else:
                myAvgLine += totcases
            
            # plot it
            plt.plot(r_data["time"][1:], weighting * totcases[1:], symbol, alpha=alpha, label=label)
            index += 1
    if index <= 1:
        return {}
    else:
        return {"myLine": weighting * myAvgLine/index, "myTime": r_data["time"]}

# %%
def readInScenario(files, prefix, lowerTimeLimit = -1, upperTimeLimit = 1000000):

    template = "^" + prefix + "*"

    myData = None
    
    for f in files:

        if(re.search(template, f) != None): # f.startswith(prefix) and 
            r_data_raw = pd.read_csv(path + f, sep='\t')

            r_data_raw = r_data_raw[r_data_raw['time'] < upperTimeLimit]
            r_data_raw = r_data_raw[r_data_raw['time'] > lowerTimeLimit]

            #we need to add an if statement here for only if it's a multidistrict model do we do this aggregation
            unique_dist_names = pd.unique(r_data_raw['myId'])
            if len(unique_dist_names) == 1:
                r_data = r_data_raw
            else:
                r_data = r_data_raw.groupby('myId', as_index=False).agg({'metric_died_count': 'max', 'metric_new_hospitalized': 'sum', 
                                    'metric_new_critical': 'sum', 'metric_new_cases_asympt': 'sum',
                                    'metric_new_cases_sympt': 'sum', 'metric_new_deaths': 'sum', 
                                    'metric_new_recovered': 'sum', 'metric_currently_infected': 'sum'})

            r_data['district'] = [int(x.split('_')[1]) for x in r_data['myId']]
            r_data['seed'] = f.split("_")[-1]
            
            if myData is None:
                myData = r_data
            else:
                myData = myData.append(r_data)
                
    return myData

# %%
# testing to make sure I know how to append dataframes
d = {'col1': [1, 2], 'col2': [3, 4]}
e = {'col1': [5, 6], 'col2': [7, 8]}
df = pd.DataFrame(data=d)
df2 = pd.DataFrame(data=e)
df.append(df2)
df
# Out:
#    col1  col2
# 0     1     3
# 1     2     4

# %%
def plotMapAtTime(file, geoDf, geoDfColname="ID_2", weighting=1, days=30): # add time cutoff -how many days?

    r_data_raw = pd.read_csv(file, sep='\t')
    #we need to add an if statement here for only if it's a multidistrict model do we do this aggregation
    unique_dist_names = pd.unique(r_data_raw['myId'])
    r_data_raw = r_data_raw[r_data_raw["time"] < days]
    
    if len(unique_dist_names) == 1:
        return
    else:
        r_data = r_data_raw.groupby('myId', as_index=False).agg({'metric_died_count': 'max', 'metric_new_hospitalized': 'sum', 
                                    'metric_new_critical': 'sum', 'metric_new_cases_asympt': 'sum',
                                    'metric_new_cases_sympt': 'sum', 'metric_new_deaths': 'sum', 
                                    'metric_new_recovered': 'sum', 'metric_currently_infected': 'sum'})

        distNum = [int(x.split('_')[1]) for x in r_data['myId']]
        r_data[geoDfColname] = distNum
        #print(r_data.head())
        #print(geoDf.head())
        for i in ['metric_died_count', 'metric_new_hospitalized', 'metric_new_critical',
                  'metric_new_cases_asympt', 'metric_new_cases_sympt',
                  'metric_new_deaths', 'metric_new_recovered', 'metric_currently_infected']:
            r_data[i] = r_data[i] * weighting

        joined = geoDf.join(r_data.set_index(geoDfColname), on=geoDfColname)
        return joined

# %%
def plotMapAtTimeFromDF(df, geoDf, geoDfColname="ID_1", weighting=1, days=30): # add time cutoff -how many days?

    #we need to add an if statement here for only if it's a multidistrict model do we do this aggregation
    unique_dist_names = pd.unique(df['myId'])
    df_raw = df[df["time"] < days]
    
    if len(unique_dist_names) == 1:
        return
    else:
        r_data = df_raw.groupby('myId', as_index=False).agg({'metric_died_count': 'max', 'metric_new_hospitalized': 'sum', 
                                    'metric_new_critical': 'sum', 'metric_new_cases_asympt': 'sum',
                                    'metric_new_cases_sympt': 'sum', 'metric_new_deaths': 'sum', 
                                    'metric_new_recovered': 'sum', 'metric_currently_infected': 'sum'})

        distNum = [int(x.split('_')[1]) for x in r_data['myId']]
        r_data[geoDfColname] = distNum
        #print(r_data.head())
        #print(geoDf.head())
        for i in ['metric_died_count', 'metric_new_hospitalized', 'metric_new_critical',
                  'metric_new_cases_asympt', 'metric_new_cases_sympt',
                  'metric_new_deaths', 'metric_new_recovered', 'metric_currently_infected']:
            r_data[i] = r_data[i] * weighting

        return joined

# %%
#path = "/Users/swise/workspace/worldbank/Disease-Modelling-SSA/data/verification/myriadOutputs/"
path = "/Users/sophieayling/Documents/GitHub/Disease-Modelling-SSA/data/output/ICCS/all"


files = os.listdir(path)

v3Files_25 = []
v3Files_5 = []

for f in files:
    if f.find("25p_v3") > 0:
        v3Files_25.append(f)
    elif f.find("_5p_v3") > 0:
        v3Files_5.append(f)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-044a9d8ae58c> in <module>
#       3
#       4
# ----> 5 files = os.listdir(path)
#       6
#       7 v3Files_25 = []
#
# NameError: name 'os' is not defined

# %%
# testing an example

prefix = "myriad_test_agg_5p_v3_" # _v1
x = readInScenario(files, prefix)
x['district'].unique()

# %% [markdown]
# ## Plot the overall numbers
#
#
# ### Line chart comparison of all three scenarios with same seed on same graph - m1, v1, v3 deaths

# %%
# the prefixes to specify each scenario
prefix_m1 = "myriad_test_agg_25p_m1_0.3_"
prefix_v1 = "myriad_test_agg_25p_v1_0.3_"
prefix_v3 = "myriad_test_agg_25p_v3_0.3_"
weight = 4

# set up the figure

fig = plt.gcf() # extracting the figure information so we can change sizes
fig.set_size_inches(8, 24) # change the plot size
sns.set(font_scale=1) # change the font size

# set up the axis holder
axlast = -1

# iterate over each seed and plot it separately
for i in range(10):
    
    # plot relative to the last axis (if that exists)
    if axlast == -1:
        axlast = plt.subplot(10, 2, i+1)
    else:
        axlast = plt.subplot(10, 2, i+1, sharey=axlast)
        
    # specify the name of this file
    subfix = str(i + 1) + ".tx"

    # plot the specific scenarios for each with the appropriate color
    plotMetric(files, prefix_m1 + subfix, ["metric_new_deaths"], 'r', 1, weight, "M1", days=90)
    plotMetric(files, prefix_v1 + subfix, ["metric_new_deaths"], 'b', 1, weight, "V1", days=90)
    plotMetric(files, prefix_v3 + subfix, ["metric_new_deaths"], 'g', 1, weight, "V3", days=90)

    # title the subplot
    plt.title("Seed: " + str(i+1))

# create the legend
lines, labels = axlast.get_legend_handles_labels()
fig.legend(lines, labels, bbox_to_anchor=(1.1, 1))

# modify the layout
plt.tight_layout()

# save the figure
fig.savefig(path + "deathRates_25perc_comparisonBySeed.png", dpi=300)

# %% [markdown]
# ### 4 panels: cases in the first 30, 60, 90 days (averages? One case study?)

# %%
# the prefixes to specify each scenario
prefix_m1 = "myriad_test_agg_25p_m1_0.3_"
prefix_v1 = "myriad_test_agg_5p_v1_0.3_"
prefix_v3 = "myriad_test_agg_5p_v3_0.3_"
weight = 20

# set up the figure
fig = plt.gcf() # extracting the figure information so we can change sizes
fig.set_size_inches(15, 12) # change the plot size
sns.set(font_scale=1) # change the font size

# the metrics
metrics = ["metric_new_cases_sympt", "metric_new_cases_asympt"]
alpha = .4
index = 1

axlast = []

# iterate over each seed and plot it separately
for i in [10, 30, 60, 90]:
    
    # plot!
    axlast = plt.subplot(2, 2, index)
    index += 1
        
    # plot the specific scenarios for each with the appropriate color
    #plotMetric(files, prefix_m1, metrics, 'r', alpha, weight, "M1", days=i)
    plotMetric(files, prefix_v1, metrics, 'b', alpha, weight, "V1", days=i)
    plotMetric(files, prefix_v3, metrics, 'y', alpha, weight, "V3", days=i)

    # title the subplot
    plt.title("First " + str(i) + " Days")

# create the legend
lines, labels = axlast.get_legend_handles_labels()
lines = lines[::10]
labels = pd.unique(labels)

fig.legend(lines, labels, bbox_to_anchor=(1.05, 1))

# modify the layout
plt.tight_layout()

# save the figure
fig.savefig(path + "caseRates_5perc_comparisonOverTime.png", dpi=300)

# %% [markdown]
# ## Geographics

# %%
zimFile = "/Users/swise/workspace/worldbank/Disease-Modelling-SSA/data/raw/shapefiles/new_districts/ZWE_adm2.shp"
zimbabwe = geopandas.read_file(zimFile)

#fig = plt.gcf() # extracting the figure information so we can change sizes
#fig.set_size_inches(15, 15) # change the plot size

ax = zimbabwe.plot(edgecolor='k', figsize=(10,10))
linelist = zimbabwe[zimbabwe["ID_2"].isin([1, 2, 18, 48])]
linelist.plot(ax=ax, edgecolor='r', linewidth=5)

fig.savefig(path + "linelist.png", dpi=300)

# %%
# Out:
#     ID_0  ISO    NAME_0  ID_1              NAME_1  ID_2     NAME_2    TYPE_2  \
# 0    256  ZWE  Zimbabwe     1            Bulawayo     1   Bulawayo  District
# 1    256  ZWE  Zimbabwe     2              Harare     2     Harare  District
# 17   256  ZWE  Zimbabwe     5    Mashonaland East    18  Goromonzi  District
# 47   256  ZWE  Zimbabwe     9  Matabeleland South    48     Gwanda  District
#
#    ENGTYPE_2 NL_NAME_2               VARNAME_2  \
# 0   District      None                    None
# 1   District      None  Salisbury|Harare Urban
# 17  District      None                    None
# 47  District      None                    None
#
#                                              geometry
# 0   POLYGON ((28.61305 -20.23587, 28.60440 -20.225...
# 1   POLYGON ((31.08852 -17.66625, 31.11038 -17.667...
# 17  POLYGON ((31.08852 -17.66625, 31.09650 -17.653...
# 47  POLYGON ((28.77732 -21.72137, 28.77868 -21.708...

# %%
# the prefixes to specify each scenario
prefix_v3_5 = "myriad_test_agg_5p_v3_0.3_"
prefix_v3_25 = "myriad_test_agg_25p_v3_0.3_"


data_25 = readInScenario(files, prefix_v3_25)

data_25.head()
# Out:
#    myId  metric_died_count  metric_new_hospitalized  metric_new_critical  \
# 0   d_1                237                     3659                  776
# 1  d_10                 72                      821                  208
# 2  d_11                 55                      573                  149
# 3  d_12                138                     1134                  337
# 4  d_13                 90                     1243                  277
#
#    metric_new_cases_asympt  metric_new_cases_sympt  metric_new_deaths  \
# 0                    48064                   81682                237
# 1                    12162                   19816                 72
# 2                     7863                   12692                 55
# 3                    14306                   23828                138
# 4                    16835                   28036                 90
#
#    metric_new_recovered  metric_currently_infected  district   seed
# 0                128697                    1319623         1  3.txt
# 1                 31928                     318609        10  3.txt
# 2                 20810                     197879        11  3.txt
# 3                 37891                     385385        12  3.txt
# 4                 44853                     450148        13  3.txt

# %%
# set up the figure
fig = plt.gcf() # extracting the figure information so we can change sizes
fig.set_size_inches(15, 18) # change the plot size
sns.set(font_scale=1) # change the font size

index = 1

axlast = []
maxFriend = [30000, 1000000, 150000]
maxIndex = 0

def plotOne(files, spatialDf, prefix, weight, time, title='Default', cmapMax=1000000):
    df = readInScenario(files, prefix, lowerTimeLimit = time - 30, upperTimeLimit = time)
    
    r_data = df.groupby('district', as_index=False).agg({'metric_died_count': 'median', 'metric_new_hospitalized': 'median', 
                                    'metric_new_critical': 'median', 'metric_new_cases_asympt': 'median',
                                    'metric_new_cases_sympt': 'median', 'metric_new_deaths': 'median', 
                                    'metric_new_recovered': 'median', 'metric_currently_infected': 'median'})

    # weight and adjust data
    for i in ['metric_died_count', 'metric_new_hospitalized', 'metric_new_critical',
                  'metric_new_cases_asympt', 'metric_new_cases_sympt',
                  'metric_new_deaths', 'metric_new_recovered', 'metric_currently_infected']:
        r_data[i] = r_data[i] * weight

    joined = spatialDf.join(r_data.set_index("district"), on="ID_2", how="left")
    joined['metric_new_cases'] = (joined['metric_new_cases_sympt'] + joined['metric_new_cases_asympt'])
    
    joined.plot(ax = axlast, column='metric_new_cases', cmap='terrain', edgecolor='k', legend=True, vmax=cmapMax)
    plt.title("Median # cases from time " + str(time-30) + " to " + str(time) + " - " + title)
    return joined

#limitFriends = [10, 150, 2500]
limitFriends = [11000, 750000, 75000] 
limitIndex = 0

for i in [30, 60, 90]:
    axlast = plt.subplot(3, 2, index)
    index += 1
    plotOne(files, zimbabwe, prefix_v3_5, 20, i, "5%", cmapMax=limitFriends[limitIndex])

    axlast = plt.subplot(3, 2, index)
    index += 1
    plotOne(files, zimbabwe, prefix_v3_25, 4, i, "25%", cmapMax=limitFriends[limitIndex])

    limitIndex += 1

# %%
zimbabwe
# Out:
#     ID_0  ISO    NAME_0  ID_1               NAME_1  ID_2            NAME_2  \
# 0    256  ZWE  Zimbabwe     1             Bulawayo     1          Bulawayo
# 1    256  ZWE  Zimbabwe     2               Harare     2            Harare
# 2    256  ZWE  Zimbabwe     3           Manicaland     3            Buhera
# 3    256  ZWE  Zimbabwe     3           Manicaland     4       Chimanimani
# 4    256  ZWE  Zimbabwe     3           Manicaland     5          Chipinge
# 5    256  ZWE  Zimbabwe     3           Manicaland     6            Makoni
# 6    256  ZWE  Zimbabwe     3           Manicaland     7            Mutare
# 7    256  ZWE  Zimbabwe     3           Manicaland     8            Mutasa
# 8    256  ZWE  Zimbabwe     3           Manicaland     9            Nyanga
# 9    256  ZWE  Zimbabwe     4  Mashonaland Central    10           Bindura
# 10   256  ZWE  Zimbabwe     4  Mashonaland Central    11         Centenary
# 11   256  ZWE  Zimbabwe     4  Mashonaland Central    12            Guruve
# 12   256  ZWE  Zimbabwe     4  Mashonaland Central    13            Mazowe
# 13   256  ZWE  Zimbabwe     4  Mashonaland Central    14      Mount Darwin
# 14   256  ZWE  Zimbabwe     4  Mashonaland Central    15          Rushinga
# 15   256  ZWE  Zimbabwe     4  Mashonaland Central    16            Shamva
# 16   256  ZWE  Zimbabwe     5     Mashonaland East    17          Chikomba
# 17   256  ZWE  Zimbabwe     5     Mashonaland East    18         Goromonzi
# 18   256  ZWE  Zimbabwe     5     Mashonaland East    19         Marondera
# 19   256  ZWE  Zimbabwe     5     Mashonaland East    20             Mudzi
# 20   256  ZWE  Zimbabwe     5     Mashonaland East    21           Murehwa
# 21   256  ZWE  Zimbabwe     5     Mashonaland East    22            Mutoko
# 22   256  ZWE  Zimbabwe     5     Mashonaland East    23              Seke
# 23   256  ZWE  Zimbabwe     5     Mashonaland East    24               UMP
# 24   256  ZWE  Zimbabwe     5     Mashonaland East    25             Wedza
# 25   256  ZWE  Zimbabwe     6     Mashonaland West    26           Chegutu
# 26   256  ZWE  Zimbabwe     6     Mashonaland West    27          Hurungwe
# 27   256  ZWE  Zimbabwe     6     Mashonaland West    28            Kadoma
# 28   256  ZWE  Zimbabwe     6     Mashonaland West    29            Kariba
# 29   256  ZWE  Zimbabwe     6     Mashonaland West    30           Makonde
# 30   256  ZWE  Zimbabwe     6     Mashonaland West    31            Zvimba
# 31   256  ZWE  Zimbabwe     7             Masvingo    32            Bikita
# 32   256  ZWE  Zimbabwe     7             Masvingo    33          Chiredzi
# 33   256  ZWE  Zimbabwe     7             Masvingo    34             Chivi
# 34   256  ZWE  Zimbabwe     7             Masvingo    35              Gutu
# 35   256  ZWE  Zimbabwe     7             Masvingo    36          Masvingo
# 36   256  ZWE  Zimbabwe     7             Masvingo    37           Mwenezi
# 37   256  ZWE  Zimbabwe     7             Masvingo    38              Zaka
# 38   256  ZWE  Zimbabwe     8   Matabeleland North    39             Binga
# 39   256  ZWE  Zimbabwe     8   Matabeleland North    40              Bubi
# 40   256  ZWE  Zimbabwe     8   Matabeleland North    41            Hwange
# 41   256  ZWE  Zimbabwe     8   Matabeleland North    42            Lupane
# 42   256  ZWE  Zimbabwe     8   Matabeleland North    43             Nkayi
# 43   256  ZWE  Zimbabwe     8   Matabeleland North    44        Tsholotsho
# 44   256  ZWE  Zimbabwe     8   Matabeleland North    45            Umguza
# 45   256  ZWE  Zimbabwe     9   Matabeleland South    46        Beitbridge
# 46   256  ZWE  Zimbabwe     9   Matabeleland South    47  Bulilima (North)
# 47   256  ZWE  Zimbabwe     9   Matabeleland South    48            Gwanda
# 48   256  ZWE  Zimbabwe     9   Matabeleland South    49            Insiza
# 49   256  ZWE  Zimbabwe     9   Matabeleland South    50    Mangwe (South)
# 50   256  ZWE  Zimbabwe     9   Matabeleland South    51            Matobo
# 51   256  ZWE  Zimbabwe     9   Matabeleland South    52        Umzingwane
# 52   256  ZWE  Zimbabwe    10             Midlands    53       Chirumhanzu
# 53   256  ZWE  Zimbabwe    10             Midlands    54       Gokwe North
# 54   256  ZWE  Zimbabwe    10             Midlands    55       Gokwe South
# 55   256  ZWE  Zimbabwe    10             Midlands    56             Gweru
# 56   256  ZWE  Zimbabwe    10             Midlands    57            Kwekwe
# 57   256  ZWE  Zimbabwe    10             Midlands    58         Mberengwa
# 58   256  ZWE  Zimbabwe    10             Midlands    59          Shurugwi
# 59   256  ZWE  Zimbabwe    10             Midlands    60        Zvishavane
#
#       TYPE_2 ENGTYPE_2 NL_NAME_2                VARNAME_2  \
# 0   District  District      None                     None
# 1   District  District      None   Salisbury|Harare Urban
# 2   District  District      None                     None
# 3   District  District      None                     None
# 4   District  District      None                     None
# 5   District  District      None                     None
# 6   District  District      None                   Umtali
# 7   District  District      None                     None
# 8   District  District      None                     None
# 9   District  District      None                     None
# 10  District  District      None              Muzarambani
# 11  District  District      None                 Sipolilo
# 12  District  District      None                     None
# 13  District  District      None                Mt Darwin
# 14  District  District      None                     None
# 15  District  District      None                     None
# 16  District  District      None                     None
# 17  District  District      None                     None
# 18  District  District      None              Marandellas
# 19  District  District      None                     None
# 20  District  District      None                     None
# 21  District  District      None                     None
# 22  District  District      None                     None
# 23  District  District      None           Murehwa U.M.P.
# 24  District  District      None                   Hwedza
# 25  District  District      None                     None
# 26  District  District      None            Karoi|Urungwe
# 27  District  District      None                  Gatooma
# 28  District  District      None                     None
# 29  District  District      None                Lomagundi
# 30  District  District      None                     None
# 31  District  District      None                     None
# 32  District  District      None                  Hartley
# 33  District  District      None                     None
# 34  District  District      None                     None
# 35  District  District      None                 Victoria
# 36  District  District      None                     None
# 37  District  District      None                     None
# 38  District  District      None                     None
# 39  District  District      None                     None
# 40  District  District      None                   Wankie
# 41  District  District      None                     None
# 42  District  District      None                     None
# 43  District  District      None                     None
# 44  District  District      None                     None
# 45  District  District      None                     None
# 46  District  District      None  Bulalimamangwe|Bulilima
# 47  District  District      None                     None
# 48  District  District      None                     None
# 49  District  District      None     Bulalimamangwe South
# 50  District  District      None                     None
# 51  District  District      None                     None
# 52  District  District      None               Chirumanzu
# 53  District  District      None                    Gokwe
# 54  District  District      None                    Gokwe
# 55  District  District      None                    Gwelo
# 56  District  District      None                  Que Que
# 57  District  District      None                Mberingwe
# 58  District  District      None                  Selukwe
# 59  District  District      None         Shabani, Shavani
#
#                                              geometry
# 0   POLYGON ((28.61305 -20.23587, 28.60440 -20.225...
# 1   POLYGON ((31.08852 -17.66625, 31.11038 -17.667...
# 2   POLYGON ((32.39763 -19.76925, 32.39830 -19.780...
# 3   POLYGON ((33.01395 -20.01098, 33.01094 -20.018...
# 4   POLYGON ((32.42310 -21.06366, 32.40906 -21.078...
# 5   POLYGON ((31.98373 -19.11975, 31.98071 -19.108...
# 6   POLYGON ((32.77855 -19.37489, 32.77308 -19.375...
# 7   POLYGON ((32.44506 -18.39830, 32.45688 -18.392...
# 8   POLYGON ((32.99868 -18.20377, 32.99176 -18.203...
# 9   POLYGON ((31.40236 -16.83971, 31.40105 -16.853...
# 10  POLYGON ((30.87200 -16.81099, 30.87432 -16.804...
# 11  POLYGON ((30.87200 -16.81099, 30.86589 -16.817...
# 12  POLYGON ((31.14483 -17.45895, 31.13451 -17.466...
# 13  POLYGON ((32.05016 -16.80723, 32.04596 -16.811...
# 14  POLYGON ((32.06152 -16.44097, 32.11372 -16.439...
# 15  POLYGON ((31.60860 -17.44868, 31.59985 -17.452...
# 16  POLYGON ((31.21511 -19.23558, 31.21128 -19.235...
# 17  POLYGON ((31.08852 -17.66625, 31.09650 -17.653...
# 18  POLYGON ((31.12500 -18.44061, 31.12739 -18.441...
# 19  POLYGON ((32.99370 -17.24492, 32.98923 -17.246...
# 20  POLYGON ((31.60860 -17.44868, 31.60833 -17.446...
# 21  POLYGON ((32.20518 -17.81340, 32.19894 -17.808...
# 22  POLYGON ((30.75946 -18.52284, 30.75798 -18.514...
# 23  POLYGON ((32.00759 -16.84432, 32.01654 -16.841...
# 24  POLYGON ((31.98373 -19.11975, 31.97173 -19.117...
# 25  POLYGON ((30.75946 -18.52284, 30.74806 -18.531...
# 26  POLYGON ((28.92984 -17.12849, 28.92847 -17.116...
# 27  POLYGON ((30.37916 -18.83976, 30.36814 -18.836...
# 28  POLYGON ((28.25459 -17.39825, 28.24942 -17.391...
# 29  POLYGON ((30.51091 -16.76356, 30.50716 -16.770...
# 30  POLYGON ((29.90731 -17.88330, 29.90350 -17.882...
# 31  POLYGON ((32.28940 -20.45568, 32.27781 -20.455...
# 32  POLYGON ((31.11290 -22.33620, 31.11252 -22.335...
# 33  POLYGON ((30.43273 -19.99366, 30.43182 -20.003...
# 34  POLYGON ((31.42000 -19.92440, 31.41427 -19.928...
# 35  POLYGON ((31.39742 -20.01721, 31.38591 -20.021...
# 36  POLYGON ((30.94402 -22.11318, 30.94206 -22.112...
# 37  POLYGON ((31.39742 -20.01721, 31.40235 -20.027...
# 38  POLYGON ((28.08174 -17.84970, 28.08144 -17.851...
# 39  POLYGON ((29.22650 -19.48012, 29.22359 -19.488...
# 40  POLYGON ((27.46796 -18.43833, 27.47824 -18.438...
# 41  POLYGON ((27.94460 -19.40311, 27.94218 -19.405...
# 42  POLYGON ((29.12566 -19.32328, 29.11988 -19.328...
# 43  POLYGON ((27.77933 -19.49440, 27.77878 -19.499...
# 44  POLYGON ((28.66857 -20.30021, 28.65701 -20.284...
# 45  POLYGON ((31.08549 -22.34456, 31.07606 -22.343...
# 46  POLYGON ((27.28497 -20.49781, 27.28372 -20.487...
# 47  POLYGON ((28.77732 -21.72137, 28.77868 -21.708...
# 48  POLYGON ((29.15939 -20.55672, 29.15635 -20.556...
# 49  POLYGON ((28.20738 -20.53341, 28.20599 -20.534...
# 50  POLYGON ((28.20738 -20.53341, 28.21135 -20.529...
# 51  POLYGON ((28.66857 -20.30021, 28.72248 -20.265...
# 52  POLYGON ((30.69757 -19.74448, 30.69663 -19.747...
# 53  POLYGON ((28.25459 -17.39825, 28.26266 -17.396...
# 54  POLYGON ((27.99771 -18.23831, 27.99968 -18.231...
# 55  POLYGON ((30.18523 -19.48782, 30.17482 -19.490...
# 56  POLYGON ((29.12566 -19.32328, 29.11995 -19.309...
# 57  POLYGON ((29.47790 -21.02500, 29.47499 -21.022...
# 58  POLYGON ((30.14902 -20.02647, 30.14320 -20.015...
# 59  POLYGON ((30.46058 -20.62785, 30.44456 -20.617...

# %%
joined1 = plotOne(files, zimbabwe, prefix_v3_5 + '10.', 20, 90, "5%")
joined2 = plotOne(files, zimbabwe, prefix_v3_25 + '10.', 4, 90, "25%")

# %%
joined2.sort_values(by="metric_died_count")
# Out:
#     ID_0  ISO    NAME_0  ID_1               NAME_1  ID_2            NAME_2  \
# 28   256  ZWE  Zimbabwe     6     Mashonaland West    29            Kariba
# 39   256  ZWE  Zimbabwe     8   Matabeleland North    40              Bubi
# 38   256  ZWE  Zimbabwe     8   Matabeleland North    39             Binga
# 50   256  ZWE  Zimbabwe     9   Matabeleland South    51            Matobo
# 49   256  ZWE  Zimbabwe     9   Matabeleland South    50    Mangwe (South)
# 51   256  ZWE  Zimbabwe     9   Matabeleland South    52        Umzingwane
# 44   256  ZWE  Zimbabwe     8   Matabeleland North    45            Umguza
# 22   256  ZWE  Zimbabwe     5     Mashonaland East    23              Seke
# 45   256  ZWE  Zimbabwe     9   Matabeleland South    46        Beitbridge
# 40   256  ZWE  Zimbabwe     8   Matabeleland North    41            Hwange
# 46   256  ZWE  Zimbabwe     9   Matabeleland South    47  Bulilima (North)
# 24   256  ZWE  Zimbabwe     5     Mashonaland East    25             Wedza
# 48   256  ZWE  Zimbabwe     9   Matabeleland South    49            Insiza
# 10   256  ZWE  Zimbabwe     4  Mashonaland Central    11         Centenary
# 14   256  ZWE  Zimbabwe     4  Mashonaland Central    15          Rushinga
# 8    256  ZWE  Zimbabwe     3           Manicaland     9            Nyanga
# 58   256  ZWE  Zimbabwe    10             Midlands    59          Shurugwi
# 9    256  ZWE  Zimbabwe     4  Mashonaland Central    10           Bindura
# 23   256  ZWE  Zimbabwe     5     Mashonaland East    24               UMP
# 3    256  ZWE  Zimbabwe     3           Manicaland     4       Chimanimani
# 15   256  ZWE  Zimbabwe     4  Mashonaland Central    16            Shamva
# 36   256  ZWE  Zimbabwe     7             Masvingo    37           Mwenezi
# 59   256  ZWE  Zimbabwe    10             Midlands    60        Zvishavane
# 29   256  ZWE  Zimbabwe     6     Mashonaland West    30           Makonde
# 52   256  ZWE  Zimbabwe    10             Midlands    53       Chirumhanzu
# 41   256  ZWE  Zimbabwe     8   Matabeleland North    42            Lupane
# 43   256  ZWE  Zimbabwe     8   Matabeleland North    44        Tsholotsho
# 18   256  ZWE  Zimbabwe     5     Mashonaland East    19         Marondera
# 42   256  ZWE  Zimbabwe     8   Matabeleland North    43             Nkayi
# 21   256  ZWE  Zimbabwe     5     Mashonaland East    22            Mutoko
# 47   256  ZWE  Zimbabwe     9   Matabeleland South    48            Gwanda
# 17   256  ZWE  Zimbabwe     5     Mashonaland East    18         Goromonzi
# 7    256  ZWE  Zimbabwe     3           Manicaland     8            Mutasa
# 53   256  ZWE  Zimbabwe    10             Midlands    54       Gokwe North
# 32   256  ZWE  Zimbabwe     7             Masvingo    33          Chiredzi
# 55   256  ZWE  Zimbabwe    10             Midlands    56             Gweru
# 31   256  ZWE  Zimbabwe     7             Masvingo    32            Bikita
# 16   256  ZWE  Zimbabwe     5     Mashonaland East    17          Chikomba
# 19   256  ZWE  Zimbabwe     5     Mashonaland East    20             Mudzi
# 57   256  ZWE  Zimbabwe    10             Midlands    58         Mberengwa
# 4    256  ZWE  Zimbabwe     3           Manicaland     5          Chipinge
# 20   256  ZWE  Zimbabwe     5     Mashonaland East    21           Murehwa
# 13   256  ZWE  Zimbabwe     4  Mashonaland Central    14      Mount Darwin
# 25   256  ZWE  Zimbabwe     6     Mashonaland West    26           Chegutu
# 33   256  ZWE  Zimbabwe     7             Masvingo    34             Chivi
# 30   256  ZWE  Zimbabwe     6     Mashonaland West    31            Zvimba
# 11   256  ZWE  Zimbabwe     4  Mashonaland Central    12            Guruve
# 27   256  ZWE  Zimbabwe     6     Mashonaland West    28            Kadoma
# 56   256  ZWE  Zimbabwe    10             Midlands    57            Kwekwe
# 12   256  ZWE  Zimbabwe     4  Mashonaland Central    13            Mazowe
# 37   256  ZWE  Zimbabwe     7             Masvingo    38              Zaka
# 35   256  ZWE  Zimbabwe     7             Masvingo    36          Masvingo
# 54   256  ZWE  Zimbabwe    10             Midlands    55       Gokwe South
# 34   256  ZWE  Zimbabwe     7             Masvingo    35              Gutu
# 26   256  ZWE  Zimbabwe     6     Mashonaland West    27          Hurungwe
# 2    256  ZWE  Zimbabwe     3           Manicaland     3            Buhera
# 5    256  ZWE  Zimbabwe     3           Manicaland     6            Makoni
# 6    256  ZWE  Zimbabwe     3           Manicaland     7            Mutare
# 0    256  ZWE  Zimbabwe     1             Bulawayo     1          Bulawayo
# 1    256  ZWE  Zimbabwe     2               Harare     2            Harare
#
#       TYPE_2 ENGTYPE_2 NL_NAME_2  ...  \
# 28  District  District      None  ...
# 39  District  District      None  ...
# 38  District  District      None  ...
# 50  District  District      None  ...
# 49  District  District      None  ...
# 51  District  District      None  ...
# 44  District  District      None  ...
# 22  District  District      None  ...
# 45  District  District      None  ...
# 40  District  District      None  ...
# 46  District  District      None  ...
# 24  District  District      None  ...
# 48  District  District      None  ...
# 10  District  District      None  ...
# 14  District  District      None  ...
# 8   District  District      None  ...
# 58  District  District      None  ...
# 9   District  District      None  ...
# 23  District  District      None  ...
# 3   District  District      None  ...
# 15  District  District      None  ...
# 36  District  District      None  ...
# 59  District  District      None  ...
# 29  District  District      None  ...
# 52  District  District      None  ...
# 41  District  District      None  ...
# 43  District  District      None  ...
# 18  District  District      None  ...
# 42  District  District      None  ...
# 21  District  District      None  ...
# 47  District  District      None  ...
# 17  District  District      None  ...
# 7   District  District      None  ...
# 53  District  District      None  ...
# 32  District  District      None  ...
# 55  District  District      None  ...
# 31  District  District      None  ...
# 16  District  District      None  ...
# 19  District  District      None  ...
# 57  District  District      None  ...
# 4   District  District      None  ...
# 20  District  District      None  ...
# 13  District  District      None  ...
# 25  District  District      None  ...
# 33  District  District      None  ...
# 30  District  District      None  ...
# 11  District  District      None  ...
# 27  District  District      None  ...
# 56  District  District      None  ...
# 12  District  District      None  ...
# 37  District  District      None  ...
# 35  District  District      None  ...
# 54  District  District      None  ...
# 34  District  District      None  ...
# 26  District  District      None  ...
# 2   District  District      None  ...
# 5   District  District      None  ...
# 6   District  District      None  ...
# 0   District  District      None  ...
# 1   District  District      None  ...
#
#                                              geometry metric_died_count  \
# 28  POLYGON ((28.25459 -17.39825, 28.24942 -17.391...                72
# 39  POLYGON ((29.22650 -19.48012, 29.22359 -19.488...               100
# 38  POLYGON ((28.08174 -17.84970, 28.08144 -17.851...               136
# 50  POLYGON ((28.20738 -20.53341, 28.21135 -20.529...               188
# 49  POLYGON ((28.20738 -20.53341, 28.20599 -20.534...               188
# 51  POLYGON ((28.66857 -20.30021, 28.72248 -20.265...               204
# 44  POLYGON ((28.66857 -20.30021, 28.65701 -20.284...               208
# 22  POLYGON ((30.75946 -18.52284, 30.75798 -18.514...               216
# 45  POLYGON ((31.08549 -22.34456, 31.07606 -22.343...               216
# 40  POLYGON ((27.46796 -18.43833, 27.47824 -18.438...               220
# 46  POLYGON ((27.28497 -20.49781, 27.28372 -20.487...               220
# 24  POLYGON ((31.98373 -19.11975, 31.97173 -19.117...               232
# 48  POLYGON ((29.15939 -20.55672, 29.15635 -20.556...               236
# 10  POLYGON ((30.87200 -16.81099, 30.87432 -16.804...               248
# 14  POLYGON ((32.06152 -16.44097, 32.11372 -16.439...               248
# 8   POLYGON ((32.99868 -18.20377, 32.99176 -18.203...               252
# 58  POLYGON ((30.14902 -20.02647, 30.14320 -20.015...               252
# 9   POLYGON ((31.40236 -16.83971, 31.40105 -16.853...               256
# 23  POLYGON ((32.00759 -16.84432, 32.01654 -16.841...               276
# 3   POLYGON ((33.01395 -20.01098, 33.01094 -20.018...               300
# 15  POLYGON ((31.60860 -17.44868, 31.59985 -17.452...               308
# 36  POLYGON ((30.94402 -22.11318, 30.94206 -22.112...               308
# 59  POLYGON ((30.46058 -20.62785, 30.44456 -20.617...               308
# 29  POLYGON ((30.51091 -16.76356, 30.50716 -16.770...               316
# 52  POLYGON ((30.69757 -19.74448, 30.69663 -19.747...               348
# 41  POLYGON ((27.94460 -19.40311, 27.94218 -19.405...               372
# 43  POLYGON ((27.77933 -19.49440, 27.77878 -19.499...               376
# 18  POLYGON ((31.12500 -18.44061, 31.12739 -18.441...               380
# 42  POLYGON ((29.12566 -19.32328, 29.11988 -19.328...               392
# 21  POLYGON ((32.20518 -17.81340, 32.19894 -17.808...               392
# 47  POLYGON ((28.77732 -21.72137, 28.77868 -21.708...               408
# 17  POLYGON ((31.08852 -17.66625, 31.09650 -17.653...               416
# 7   POLYGON ((32.44506 -18.39830, 32.45688 -18.392...               420
# 53  POLYGON ((28.25459 -17.39825, 28.26266 -17.396...               428
# 32  POLYGON ((31.11290 -22.33620, 31.11252 -22.335...               432
# 55  POLYGON ((30.18523 -19.48782, 30.17482 -19.490...               456
# 31  POLYGON ((32.28940 -20.45568, 32.27781 -20.455...               468
# 16  POLYGON ((31.21511 -19.23558, 31.21128 -19.235...               468
# 19  POLYGON ((32.99370 -17.24492, 32.98923 -17.246...               484
# 57  POLYGON ((29.47790 -21.02500, 29.47499 -21.022...               492
# 4   POLYGON ((32.42310 -21.06366, 32.40906 -21.078...               504
# 20  POLYGON ((31.60860 -17.44868, 31.60833 -17.446...               508
# 13  POLYGON ((32.05016 -16.80723, 32.04596 -16.811...               512
# 25  POLYGON ((30.75946 -18.52284, 30.74806 -18.531...               512
# 33  POLYGON ((30.43273 -19.99366, 30.43182 -20.003...               532
# 30  POLYGON ((29.90731 -17.88330, 29.90350 -17.882...               532
# 11  POLYGON ((30.87200 -16.81099, 30.86589 -16.817...               544
# 27  POLYGON ((30.37916 -18.83976, 30.36814 -18.836...               548
# 56  POLYGON ((29.12566 -19.32328, 29.11995 -19.309...               552
# 12  POLYGON ((31.14483 -17.45895, 31.13451 -17.466...               560
# 37  POLYGON ((31.39742 -20.01721, 31.40235 -20.027...               572
# 35  POLYGON ((31.39742 -20.01721, 31.38591 -20.021...               620
# 54  POLYGON ((27.99771 -18.23831, 27.99968 -18.231...               632
# 34  POLYGON ((31.42000 -19.92440, 31.41427 -19.928...               668
# 26  POLYGON ((28.92984 -17.12849, 28.92847 -17.116...               704
# 2   POLYGON ((32.39763 -19.76925, 32.39830 -19.780...               732
# 5   POLYGON ((31.98373 -19.11975, 31.98071 -19.108...               792
# 6   POLYGON ((32.77855 -19.37489, 32.77308 -19.375...               852
# 0   POLYGON ((28.61305 -20.23587, 28.60440 -20.225...              1052
# 1   POLYGON ((31.08852 -17.66625, 31.11038 -17.667...              2380
#
#     metric_new_hospitalized  metric_new_critical  metric_new_cases_asympt  \
# 28                     1060                  220                    10100
# 39                      868                  244                     3640
# 38                     3092                  756                    32392
# 50                     2232                  648                    14580
# 49                     1668                  500                    11644
# 51                     1208                  444                     4516
# 44                     1612                  448                     6244
# 22                     1440                  348                     3660
# 45                     1888                  508                     8928
# 40                     2404                  564                    22284
# 46                     2200                  696                    13588
# 24                     1252                  424                     3232
# 48                     1532                  460                     6600
# 10                     1832                  556                     8528
# 14                     1304                  540                     6372
# 8                      2560                  792                    15056
# 58                     1872                  544                     6696
# 9                      2036                  500                     7880
# 23                     2100                  616                     8288
# 3                      2548                  668                    16700
# 15                     1668                  624                     6304
# 36                     2504                  656                    12348
# 59                     2144                  716                    10084
# 29                     3084                  732                    12084
# 52                     1580                  528                     4488
# 41                     2188                  808                    12524
# 43                     2672                  872                    14776
# 18                     2524                  728                     6588
# 42                     2272                  836                    14288
# 21                     3020                  976                    12576
# 47                     2968                 1068                    16388
# 17                     3092                  776                     8436
# 7                      3360                 1164                    15948
# 53                     3952                 1248                    29516
# 32                     4540                 1052                    32868
# 55                     4060                 1036                    18448
# 31                     2988                  932                    10928
# 16                     2424                  940                     6060
# 19                     2692                 1016                    12916
# 57                     2952                 1132                    13304
# 4                      5768                 1548                    49072
# 20                     2864                 1116                     7684
# 13                     3840                 1300                    16716
# 25                     3180                  904                     8600
# 33                     2848                 1116                    10444
# 30                     3284                  888                     8824
# 11                     3536                 1072                    14500
# 27                     4064                 1076                    17076
# 56                     5204                 1376                    27824
# 12                     2768                  840                     7256
# 37                     3192                 1148                    11068
# 35                     4880                 1232                    19792
# 54                     5220                 1496                    34288
# 34                     3888                 1328                    10564
# 26                     6080                 1920                    38620
# 2                      4620                 1552                    17732
# 5                      5096                 1868                    18260
# 6                      7540                 2024                    45416
# 0                     10456                 2472                    43896
# 1                     20144                 4272                    55384
#
#     metric_new_cases_sympt  metric_new_deaths  metric_new_recovered  \
# 28                   15652                 72                 45920
# 39                    5628                100                 32448
# 38                   53352                136                 93976
# 50                   26128                184                 62844
# 49                   19448                184                 50340
# 51                    7700                196                 38064
# 44                   10380                204                 52720
# 22                    5940                196                 53036
# 45                   14956                212                 71160
# 40                   39536                216                 97892
# 46                   23272                220                 60032
# 24                    5748                220                 37628
# 48                   10872                220                 53692
# 10                   14316                248                 67080
# 14                   10504                248                 42304
# 8                    25088                244                 80988
# 58                   11292                248                 56560
# 9                    13252                252                 89304
# 23                   14120                268                 65200
# 3                    27360                292                 88404
# 15                   10312                304                 64868
# 36                   19380                304                 90816
# 59                   16452                304                 74288
# 29                   20656                308                126792
# 52                    7712                344                 43496
# 41                   20908                372                 61720
# 43                   25304                368                 71552
# 18                   11748                368                 88772
# 42                   23516                388                 66580
# 21                   21548                388                 88304
# 47                   27728                408                 86424
# 17                   15276                400                135244
# 7                    27892                416                105576
# 53                   45408                412                148184
# 32                   54432                424                183944
# 55                   31088                444                153300
# 31                   18264                460                 90692
# 16                   10752                448                 63716
# 19                   21812                484                 79648
# 57                   22140                484                101520
# 4                    79156                504                206620
# 20                   12944                504                 94708
# 13                   28576                508                128556
# 25                   15204                492                126672
# 33                   17484                516                 88060
# 30                   15248                488                138820
# 11                   23960                536                119384
# 27                   29024                528                169000
# 56                   46956                548                192732
# 12                   12424                544                111036
# 37                   18784                540                 95104
# 35                   33724                600                172644
# 54                   56228                624                196780
# 34                   18940                652                104476
# 26                   64832                692                224892
# 2                    30560                712                136240
# 5                    31640                768                163616
# 6                    75144                836                284720
# 0                    76148               1020                388276
# 1                    92376               2224                952480
#
#     metric_currently_infected  metric_new_cases
# 28                     403368             25752
# 39                     227440              9268
# 38                     943280             85744
# 50                     567916             40708
# 49                     450276             31092
# 51                     309532             12216
# 44                     392032             16624
# 22                     453536              9600
# 45                     553840             23884
# 40                     885208             61820
# 46                     545288             36860
# 24                     267696              8980
# 48                     364116             17472
# 10                     456636             22844
# 14                     319684             16876
# 8                      670324             40144
# 58                     454544             17988
# 9                      642560             21132
# 23                     494444             22408
# 3                      745552             44060
# 15                     434448             16616
# 36                     713392             31728
# 59                     612716             26536
# 29                     873820             32740
# 52                     307928             12200
# 41                     530188             33432
# 43                     628496             40080
# 18                     583684             18336
# 42                     578440             37804
# 21                     722092             34124
# 47                     739500             44116
# 17                    1018452             23712
# 7                      883180             43840
# 53                    1245236             74924
# 32                    1493320             87300
# 55                    1168932             49536
# 31                     696284             29192
# 16                     474856             16812
# 19                     635156             34728
# 57                     729372             35444
# 4                     1836404            128228
# 20                     601056             20628
# 13                    1041696             45292
# 25                     786652             23804
# 33                     632948             27928
# 30                    1123056             24072
# 11                     919764             38460
# 27                    1224080             46100
# 56                    1529668             74780
# 12                     690432             19680
# 37                     661580             29852
# 35                    1441752             53516
# 54                    1571576             90516
# 34                     750880             29504
# 26                    1835864            103452
# 2                     1020156             48292
# 5                     1186296             49900
# 6                     2348148            120560
# 0                     2965604            120044
# 1                     5675260            147760
#
# [60 rows x 21 columns]

# %%
myMet = "metric_new_deaths"
joined1['death_diff'] = (joined2[myMet] - joined1[myMet]) / joined1[myMet]

# set up the figure
fig = plt.gcf() # extracting the figure information so we can change sizes
fig.set_size_inches(15, 10) # change the plot size
sns.set(font_scale=1.25) # change the font size

axlast = plt.subplot(1, 2, 1)
joined1.plot(ax=axlast, column='metric_new_deaths', cmap='Spectral', edgecolor='k', vmax=2250)
plt.title("Deaths from time 60 to 90 - 5% Sample")

axlast = plt.subplot(1, 2, 2)
sm = joined2.plot(ax=axlast, column='metric_new_deaths', cmap='Spectral', edgecolor='k', vmax=2250)
plt.title("Deaths from time 60 to 90 - 25% Sample")

sm = plt.cm.ScalarMappable(cmap='Spectral', norm=plt.Normalize(vmin=0, vmax=2250))
fig.colorbar(sm)


# modify the layout
plt.tight_layout()

fig.savefig(path + "comparisonOfDeathsOverTime.png", dpi=300)

# %%
for i in [30, 60, 90]:
    
    df = readInScenario(files, prefix_v3_5, lowerTimeLimit = i - 30, upperTimeLimit = i)

    r_data = df.groupby('district', as_index=False).agg({'metric_died_count': 'median', 'metric_new_hospitalized': 'median', 
                                    'metric_new_critical': 'median', 'metric_new_cases_asympt': 'median',
                                    'metric_new_cases_sympt': 'median', 'metric_new_deaths': 'median', 
                                    'metric_new_recovered': 'median', 'metric_currently_infected': 'median'})

    # plot!
    axlast = plt.subplot(3, 2, index)
    index += 1

    joined = zimbabwe.join(r_data.set_index("district"), on="ID_1")
    joined['metric_new_cases'] = 20 * (joined['metric_new_cases_sympt'] + joined['metric_new_cases_asympt'])
    joined.plot(ax = axlast, column='metric_died_count', cmap='rainbow', edgecolor='k', legend=True)#, vmax=maxFriend[maxIndex])
    plt.title("Median # cases from time " + str(i-30) + " to " + str(i) + " - 5%")
    
    df = readInScenario(files, prefix_v3_25, lowerTimeLimit = i - 30, upperTimeLimit = i)

    r_data = df.groupby('district', as_index=False).agg({'metric_died_count': 'median', 'metric_new_hospitalized': 'median', 
                                    'metric_new_critical': 'median', 'metric_new_cases_asympt': 'median',
                                    'metric_new_cases_sympt': 'median', 'metric_new_deaths': 'median', 
                                    'metric_new_recovered': 'median', 'metric_currently_infected': 'median'})

    # plot!
    axlast = plt.subplot(3, 2, index)
    index += 1

    joined = zimbabwe.join(r_data.set_index("district"), on="ID_1")
    joined['metric_new_cases'] = 4 * (joined['metric_new_cases_sympt'] + joined['metric_new_cases_asympt'])
    joined.plot(ax = axlast, column='metric_died_count', cmap='rainbow', edgecolor='k', legend=True)#, vmax=maxFriend[maxIndex])
    plt.title("Median # cases from time " + str(i-30) + " to " + str(i) + " - 25%")
    
    maxIndex += 1
    
# save the figure
fig.savefig(path + "caseCounts_mapOverTime.png", dpi=300)

# %%
def plotMapAtTimeFromDF(df, geoDf, geoDfColname="ID_1", weighting=1, days=30): # add time cutoff -how many days?

    #we need to add an if statement here for only if it's a multidistrict model do we do this aggregation
    unique_dist_names = pd.unique(df['myId'])
    df_raw = df[df["time"] < days]
    
    if len(unique_dist_names) == 1:
        return
    else:

        distNum = [int(x.split('_')[1]) for x in r_data['myId']]
        r_data[geoDfColname] = distNum
        #print(r_data.head())
        #print(geoDf.head())
        for i in ['metric_died_count', 'metric_new_hospitalized', 'metric_new_critical',
                  'metric_new_cases_asympt', 'metric_new_cases_sympt',
                  'metric_new_deaths', 'metric_new_recovered', 'metric_currently_infected']:
            r_data[i] = r_data[i] * weighting

        return joined

# %%
fig = plt.figure()

data = v3Files_5
weighting = 20

fig, axs = plt.subplots(nrows=len(data), figsize=(10,40))

for i in range(len(data)):
    x = plotMapAtTime(path + data[i], zimbabwe, weighting=weighting, days=60)
    x.plot(ax=axs[i], column='metric_died_count', cmap='OrRd', edgecolor='k', legend=True)
    #ax.title(v3Files_5[i])

fig.savefig(path + "5_results.png", dpi=300)

# %% [markdown]
# ## Other things

# %%
prefix = "myriad_test_agg_5p_" # _v1


fig = plt.gcf() # extracting the figure information so we can change sizes
fig.set_size_inches(15, 8) # change the plot size
sns.set(font_scale=2) # change the font size
    
params = ["m1_", "v1_", "v3_"]
my5Style = "-"
colors = ['b', 'y', 'g']
for i in range(len(params)):
    plotMetric(files, prefix + params[i], ["metric_new_deaths"], colors[i] + my5Style, .3, 20, params[i], days=90)



prefix = "myriad_test_agg_25p_" # _v1    
my25Style = "--"
for i in range(len(params)):
    plotMetric(files, prefix + params[i], ["metric_new_deaths"], colors[i] + my25Style, 1, 4, params[i], days=90)


#plt.legend(params)

#plt.savefig(path + "1DistNoWknds_beta_comps_90days.png", dpi=300)

# %%
path = "/Users/swise/workspace/worldbank/Disease-Modelling-SSA/data/verification/myriadOutputs/"
#path = "/Users/swise/workspace/worldbank/Disease-Modelling-SSA/data/verification/single_district/"

files = os.listdir(path)



fig = plt.gcf() # extracting the figure information so we can change sizes
fig.set_size_inches(15, 8) # change the plot size
sns.set(font_scale=2) # change the font size
    
params = ["m1_", "v1_", "v3_"]
my5Style = "-"
colors = ['b', 'y', 'g']
dayLimit = 10
metrics = ["metric_new_cases_sympt", "metric_new_cases_asympt"]

prefix = "myriad_test_agg_5p_" # _v1    
x = plotMetric(files, prefix + "m1_0.3_8_", metrics, 'b' + my5Style, 1, 20, "m1", days=dayLimit)
x = plotMetric(files, prefix + "v1_0.3_8_", metrics, 'y' + my5Style, 1, 20, "v1", days=dayLimit)
x = plotMetric(files, prefix + "v3_0.3_8_", metrics, 'g' + my5Style, 1, 20, "v3", days=dayLimit)

prefix = "myriad_test_agg_25p_" # _v1    
x = plotMetric(files, prefix + "m1_0.3_8_", metrics, 'b' + my25Style, 1, 4, "m1", days=dayLimit)
x = plotMetric(files, prefix + "v1_0.3_8_", metrics, 'y' + my25Style, 1, 4, "v1", days=dayLimit)
x = plotMetric(files, prefix + "v3_0.3_8_", metrics, 'g' + my25Style, 1, 4, "v3", days=dayLimit)

# %%
fig = plt.gcf() # extracting the figure information so we can change sizes
fig.set_size_inches(15, 8) # change the plot size
sns.set(font_scale=2) # change the font size

x = plotMetric(files, "myriad_test_agg_5p_" + "v1_", ["metric_new_deaths"], 'r-', .8, 20, "5%")
x = plotMetric(files, "myriad_test_agg_25p_" + "v1_", ["metric_new_deaths"], 'b--', .8, 4, "25%")

# %% [markdown]
# ## Plot the geographies

# %%
testing = v3Files_5[1]
print(testing)
x = plotMapAtTime(path + testing, zimbabwe, weighting=5)
x.plot(column='metric_new_deaths', cmap='OrRd', edgecolor='k', legend=True)
sum(x["metric_died_count"])
x
# Out:
# myriad_test_agg_5p_v3_0.3_8.txt
#     ID_0  ISO    NAME_0  ID_1               NAME_1  ID_2            NAME_2  \
# 0    256  ZWE  Zimbabwe     1             Bulawayo     1          Bulawayo
# 1    256  ZWE  Zimbabwe     2               Harare     2            Harare
# 2    256  ZWE  Zimbabwe     3           Manicaland     3            Buhera
# 3    256  ZWE  Zimbabwe     3           Manicaland     4       Chimanimani
# 4    256  ZWE  Zimbabwe     3           Manicaland     5          Chipinge
# 5    256  ZWE  Zimbabwe     3           Manicaland     6            Makoni
# 6    256  ZWE  Zimbabwe     3           Manicaland     7            Mutare
# 7    256  ZWE  Zimbabwe     3           Manicaland     8            Mutasa
# 8    256  ZWE  Zimbabwe     3           Manicaland     9            Nyanga
# 9    256  ZWE  Zimbabwe     4  Mashonaland Central    10           Bindura
# 10   256  ZWE  Zimbabwe     4  Mashonaland Central    11         Centenary
# 11   256  ZWE  Zimbabwe     4  Mashonaland Central    12            Guruve
# 12   256  ZWE  Zimbabwe     4  Mashonaland Central    13            Mazowe
# 13   256  ZWE  Zimbabwe     4  Mashonaland Central    14      Mount Darwin
# 14   256  ZWE  Zimbabwe     4  Mashonaland Central    15          Rushinga
# 15   256  ZWE  Zimbabwe     4  Mashonaland Central    16            Shamva
# 16   256  ZWE  Zimbabwe     5     Mashonaland East    17          Chikomba
# 17   256  ZWE  Zimbabwe     5     Mashonaland East    18         Goromonzi
# 18   256  ZWE  Zimbabwe     5     Mashonaland East    19         Marondera
# 19   256  ZWE  Zimbabwe     5     Mashonaland East    20             Mudzi
# 20   256  ZWE  Zimbabwe     5     Mashonaland East    21           Murehwa
# 21   256  ZWE  Zimbabwe     5     Mashonaland East    22            Mutoko
# 22   256  ZWE  Zimbabwe     5     Mashonaland East    23              Seke
# 23   256  ZWE  Zimbabwe     5     Mashonaland East    24               UMP
# 24   256  ZWE  Zimbabwe     5     Mashonaland East    25             Wedza
# 25   256  ZWE  Zimbabwe     6     Mashonaland West    26           Chegutu
# 26   256  ZWE  Zimbabwe     6     Mashonaland West    27          Hurungwe
# 27   256  ZWE  Zimbabwe     6     Mashonaland West    28            Kadoma
# 28   256  ZWE  Zimbabwe     6     Mashonaland West    29            Kariba
# 29   256  ZWE  Zimbabwe     6     Mashonaland West    30           Makonde
# 30   256  ZWE  Zimbabwe     6     Mashonaland West    31            Zvimba
# 31   256  ZWE  Zimbabwe     7             Masvingo    32            Bikita
# 32   256  ZWE  Zimbabwe     7             Masvingo    33          Chiredzi
# 33   256  ZWE  Zimbabwe     7             Masvingo    34             Chivi
# 34   256  ZWE  Zimbabwe     7             Masvingo    35              Gutu
# 35   256  ZWE  Zimbabwe     7             Masvingo    36          Masvingo
# 36   256  ZWE  Zimbabwe     7             Masvingo    37           Mwenezi
# 37   256  ZWE  Zimbabwe     7             Masvingo    38              Zaka
# 38   256  ZWE  Zimbabwe     8   Matabeleland North    39             Binga
# 39   256  ZWE  Zimbabwe     8   Matabeleland North    40              Bubi
# 40   256  ZWE  Zimbabwe     8   Matabeleland North    41            Hwange
# 41   256  ZWE  Zimbabwe     8   Matabeleland North    42            Lupane
# 42   256  ZWE  Zimbabwe     8   Matabeleland North    43             Nkayi
# 43   256  ZWE  Zimbabwe     8   Matabeleland North    44        Tsholotsho
# 44   256  ZWE  Zimbabwe     8   Matabeleland North    45            Umguza
# 45   256  ZWE  Zimbabwe     9   Matabeleland South    46        Beitbridge
# 46   256  ZWE  Zimbabwe     9   Matabeleland South    47  Bulilima (North)
# 47   256  ZWE  Zimbabwe     9   Matabeleland South    48            Gwanda
# 48   256  ZWE  Zimbabwe     9   Matabeleland South    49            Insiza
# 49   256  ZWE  Zimbabwe     9   Matabeleland South    50    Mangwe (South)
# 50   256  ZWE  Zimbabwe     9   Matabeleland South    51            Matobo
# 51   256  ZWE  Zimbabwe     9   Matabeleland South    52        Umzingwane
# 52   256  ZWE  Zimbabwe    10             Midlands    53       Chirumhanzu
# 53   256  ZWE  Zimbabwe    10             Midlands    54       Gokwe North
# 54   256  ZWE  Zimbabwe    10             Midlands    55       Gokwe South
# 55   256  ZWE  Zimbabwe    10             Midlands    56             Gweru
# 56   256  ZWE  Zimbabwe    10             Midlands    57            Kwekwe
# 57   256  ZWE  Zimbabwe    10             Midlands    58         Mberengwa
# 58   256  ZWE  Zimbabwe    10             Midlands    59          Shurugwi
# 59   256  ZWE  Zimbabwe    10             Midlands    60        Zvishavane
#
#       TYPE_2 ENGTYPE_2 NL_NAME_2  ...  \
# 0   District  District      None  ...
# 1   District  District      None  ...
# 2   District  District      None  ...
# 3   District  District      None  ...
# 4   District  District      None  ...
# 5   District  District      None  ...
# 6   District  District      None  ...
# 7   District  District      None  ...
# 8   District  District      None  ...
# 9   District  District      None  ...
# 10  District  District      None  ...
# 11  District  District      None  ...
# 12  District  District      None  ...
# 13  District  District      None  ...
# 14  District  District      None  ...
# 15  District  District      None  ...
# 16  District  District      None  ...
# 17  District  District      None  ...
# 18  District  District      None  ...
# 19  District  District      None  ...
# 20  District  District      None  ...
# 21  District  District      None  ...
# 22  District  District      None  ...
# 23  District  District      None  ...
# 24  District  District      None  ...
# 25  District  District      None  ...
# 26  District  District      None  ...
# 27  District  District      None  ...
# 28  District  District      None  ...
# 29  District  District      None  ...
# 30  District  District      None  ...
# 31  District  District      None  ...
# 32  District  District      None  ...
# 33  District  District      None  ...
# 34  District  District      None  ...
# 35  District  District      None  ...
# 36  District  District      None  ...
# 37  District  District      None  ...
# 38  District  District      None  ...
# 39  District  District      None  ...
# 40  District  District      None  ...
# 41  District  District      None  ...
# 42  District  District      None  ...
# 43  District  District      None  ...
# 44  District  District      None  ...
# 45  District  District      None  ...
# 46  District  District      None  ...
# 47  District  District      None  ...
# 48  District  District      None  ...
# 49  District  District      None  ...
# 50  District  District      None  ...
# 51  District  District      None  ...
# 52  District  District      None  ...
# 53  District  District      None  ...
# 54  District  District      None  ...
# 55  District  District      None  ...
# 56  District  District      None  ...
# 57  District  District      None  ...
# 58  District  District      None  ...
# 59  District  District      None  ...
#
#                                              geometry  myId metric_died_count  \
# 0   POLYGON ((28.61305 -20.23587, 28.60440 -20.225...   d_1                 0
# 1   POLYGON ((31.08852 -17.66625, 31.11038 -17.667...   d_2                 0
# 2   POLYGON ((32.39763 -19.76925, 32.39830 -19.780...   d_3                 0
# 3   POLYGON ((33.01395 -20.01098, 33.01094 -20.018...   d_3                 0
# 4   POLYGON ((32.42310 -21.06366, 32.40906 -21.078...   d_3                 0
# 5   POLYGON ((31.98373 -19.11975, 31.98071 -19.108...   d_3                 0
# 6   POLYGON ((32.77855 -19.37489, 32.77308 -19.375...   d_3                 0
# 7   POLYGON ((32.44506 -18.39830, 32.45688 -18.392...   d_3                 0
# 8   POLYGON ((32.99868 -18.20377, 32.99176 -18.203...   d_3                 0
# 9   POLYGON ((31.40236 -16.83971, 31.40105 -16.853...   d_4                 0
# 10  POLYGON ((30.87200 -16.81099, 30.87432 -16.804...   d_4                 0
# 11  POLYGON ((30.87200 -16.81099, 30.86589 -16.817...   d_4                 0
# 12  POLYGON ((31.14483 -17.45895, 31.13451 -17.466...   d_4                 0
# 13  POLYGON ((32.05016 -16.80723, 32.04596 -16.811...   d_4                 0
# 14  POLYGON ((32.06152 -16.44097, 32.11372 -16.439...   d_4                 0
# 15  POLYGON ((31.60860 -17.44868, 31.59985 -17.452...   d_4                 0
# 16  POLYGON ((31.21511 -19.23558, 31.21128 -19.235...   d_5                 0
# 17  POLYGON ((31.08852 -17.66625, 31.09650 -17.653...   d_5                 0
# 18  POLYGON ((31.12500 -18.44061, 31.12739 -18.441...   d_5                 0
# 19  POLYGON ((32.99370 -17.24492, 32.98923 -17.246...   d_5                 0
# 20  POLYGON ((31.60860 -17.44868, 31.60833 -17.446...   d_5                 0
# 21  POLYGON ((32.20518 -17.81340, 32.19894 -17.808...   d_5                 0
# 22  POLYGON ((30.75946 -18.52284, 30.75798 -18.514...   d_5                 0
# 23  POLYGON ((32.00759 -16.84432, 32.01654 -16.841...   d_5                 0
# 24  POLYGON ((31.98373 -19.11975, 31.97173 -19.117...   d_5                 0
# 25  POLYGON ((30.75946 -18.52284, 30.74806 -18.531...   d_6                 0
# 26  POLYGON ((28.92984 -17.12849, 28.92847 -17.116...   d_6                 0
# 27  POLYGON ((30.37916 -18.83976, 30.36814 -18.836...   d_6                 0
# 28  POLYGON ((28.25459 -17.39825, 28.24942 -17.391...   d_6                 0
# 29  POLYGON ((30.51091 -16.76356, 30.50716 -16.770...   d_6                 0
# 30  POLYGON ((29.90731 -17.88330, 29.90350 -17.882...   d_6                 0
# 31  POLYGON ((32.28940 -20.45568, 32.27781 -20.455...   d_7                 0
# 32  POLYGON ((31.11290 -22.33620, 31.11252 -22.335...   d_7                 0
# 33  POLYGON ((30.43273 -19.99366, 30.43182 -20.003...   d_7                 0
# 34  POLYGON ((31.42000 -19.92440, 31.41427 -19.928...   d_7                 0
# 35  POLYGON ((31.39742 -20.01721, 31.38591 -20.021...   d_7                 0
# 36  POLYGON ((30.94402 -22.11318, 30.94206 -22.112...   d_7                 0
# 37  POLYGON ((31.39742 -20.01721, 31.40235 -20.027...   d_7                 0
# 38  POLYGON ((28.08174 -17.84970, 28.08144 -17.851...   d_8                 0
# 39  POLYGON ((29.22650 -19.48012, 29.22359 -19.488...   d_8                 0
# 40  POLYGON ((27.46796 -18.43833, 27.47824 -18.438...   d_8                 0
# 41  POLYGON ((27.94460 -19.40311, 27.94218 -19.405...   d_8                 0
# 42  POLYGON ((29.12566 -19.32328, 29.11988 -19.328...   d_8                 0
# 43  POLYGON ((27.77933 -19.49440, 27.77878 -19.499...   d_8                 0
# 44  POLYGON ((28.66857 -20.30021, 28.65701 -20.284...   d_8                 0
# 45  POLYGON ((31.08549 -22.34456, 31.07606 -22.343...   d_9                 0
# 46  POLYGON ((27.28497 -20.49781, 27.28372 -20.487...   d_9                 0
# 47  POLYGON ((28.77732 -21.72137, 28.77868 -21.708...   d_9                 0
# 48  POLYGON ((29.15939 -20.55672, 29.15635 -20.556...   d_9                 0
# 49  POLYGON ((28.20738 -20.53341, 28.20599 -20.534...   d_9                 0
# 50  POLYGON ((28.20738 -20.53341, 28.21135 -20.529...   d_9                 0
# 51  POLYGON ((28.66857 -20.30021, 28.72248 -20.265...   d_9                 0
# 52  POLYGON ((30.69757 -19.74448, 30.69663 -19.747...  d_10                 0
# 53  POLYGON ((28.25459 -17.39825, 28.26266 -17.396...  d_10                 0
# 54  POLYGON ((27.99771 -18.23831, 27.99968 -18.231...  d_10                 0
# 55  POLYGON ((30.18523 -19.48782, 30.17482 -19.490...  d_10                 0
# 56  POLYGON ((29.12566 -19.32328, 29.11995 -19.309...  d_10                 0
# 57  POLYGON ((29.47790 -21.02500, 29.47499 -21.022...  d_10                 0
# 58  POLYGON ((30.14902 -20.02647, 30.14320 -20.015...  d_10                 0
# 59  POLYGON ((30.46058 -20.62785, 30.44456 -20.617...  d_10                 0
#
#     metric_new_hospitalized  metric_new_critical  metric_new_cases_asympt  \
# 0                         5                    0                      265
# 1                        15                    5                     2045
# 2                         0                    0                       90
# 3                         0                    0                       90
# 4                         0                    0                       90
# 5                         0                    0                       90
# 6                         0                    0                       90
# 7                         0                    0                       90
# 8                         0                    0                       90
# 9                         0                    0                       35
# 10                        0                    0                       35
# 11                        0                    0                       35
# 12                        0                    0                       35
# 13                        0                    0                       35
# 14                        0                    0                       35
# 15                        0                    0                       35
# 16                        0                    0                       30
# 17                        0                    0                       30
# 18                        0                    0                       30
# 19                        0                    0                       30
# 20                        0                    0                       30
# 21                        0                    0                       30
# 22                        0                    0                       30
# 23                        0                    0                       30
# 24                        0                    0                       30
# 25                        5                    0                       40
# 26                        5                    0                       40
# 27                        5                    0                       40
# 28                        5                    0                       40
# 29                        5                    0                       40
# 30                        5                    0                       40
# 31                        5                    0                      100
# 32                        5                    0                      100
# 33                        5                    0                      100
# 34                        5                    0                      100
# 35                        5                    0                      100
# 36                        5                    0                      100
# 37                        5                    0                      100
# 38                        0                    0                       15
# 39                        0                    0                       15
# 40                        0                    0                       15
# 41                        0                    0                       15
# 42                        0                    0                       15
# 43                        0                    0                       15
# 44                        0                    0                       15
# 45                        0                    0                       55
# 46                        0                    0                       55
# 47                        0                    0                       55
# 48                        0                    0                       55
# 49                        0                    0                       55
# 50                        0                    0                       55
# 51                        0                    0                       55
# 52                        0                    0                       45
# 53                        0                    0                       45
# 54                        0                    0                       45
# 55                        0                    0                       45
# 56                        0                    0                       45
# 57                        0                    0                       45
# 58                        0                    0                       45
# 59                        0                    0                       45
#
#     metric_new_cases_sympt  metric_new_deaths  metric_new_recovered  \
# 0                      410                  0                    95
# 1                     3095                  0                   960
# 2                       95                  0                    50
# 3                       95                  0                    50
# 4                       95                  0                    50
# 5                       95                  0                    50
# 6                       95                  0                    50
# 7                       95                  0                    50
# 8                       95                  0                    50
# 9                       15                  0                     5
# 10                      15                  0                     5
# 11                      15                  0                     5
# 12                      15                  0                     5
# 13                      15                  0                     5
# 14                      15                  0                     5
# 15                      15                  0                     5
# 16                      85                  0                     5
# 17                      85                  0                     5
# 18                      85                  0                     5
# 19                      85                  0                     5
# 20                      85                  0                     5
# 21                      85                  0                     5
# 22                      85                  0                     5
# 23                      85                  0                     5
# 24                      85                  0                     5
# 25                     120                  0                    20
# 26                     120                  0                    20
# 27                     120                  0                    20
# 28                     120                  0                    20
# 29                     120                  0                    20
# 30                     120                  0                    20
# 31                      50                  0                    25
# 32                      50                  0                    25
# 33                      50                  0                    25
# 34                      50                  0                    25
# 35                      50                  0                    25
# 36                      50                  0                    25
# 37                      50                  0                    25
# 38                      45                  0                     0
# 39                      45                  0                     0
# 40                      45                  0                     0
# 41                      45                  0                     0
# 42                      45                  0                     0
# 43                      45                  0                     0
# 44                      45                  0                     0
# 45                      15                  0                     5
# 46                      15                  0                     5
# 47                      15                  0                     5
# 48                      15                  0                     5
# 49                      15                  0                     5
# 50                      15                  0                     5
# 51                      15                  0                     5
# 52                     110                  0                    30
# 53                     110                  0                    30
# 54                     110                  0                    30
# 55                     110                  0                    30
# 56                     110                  0                    30
# 57                     110                  0                    30
# 58                     110                  0                    30
# 59                     110                  0                    30
#
#     metric_currently_infected
# 0                        2685
# 1                       22195
# 2                         960
# 3                         960
# 4                         960
# 5                         960
# 6                         960
# 7                         960
# 8                         960
# 9                         170
# 10                        170
# 11                        170
# 12                        170
# 13                        170
# 14                        170
# 15                        170
# 16                        400
# 17                        400
# 18                        400
# 19                        400
# 20                        400
# 21                        400
# 22                        400
# 23                        400
# 24                        400
# 25                        530
# 26                        530
# 27                        530
# 28                        530
# 29                        530
# 30                        530
# 31                        450
# 32                        450
# 33                        450
# 34                        450
# 35                        450
# 36                        450
# 37                        450
# 38                         70
# 39                         70
# 40                         70
# 41                         70
# 42                         70
# 43                         70
# 44                         70
# 45                        215
# 46                        215
# 47                        215
# 48                        215
# 49                        215
# 50                        215
# 51                        215
# 52                        775
# 53                        775
# 54                        775
# 55                        775
# 56                        775
# 57                        775
# 58                        775
# 59                        775
#
# [60 rows x 21 columns]

# %%
testing = v3Files_25[1]
print(testing)
x = plotMapAtTime(path + testing, zimbabwe, weighting=1)
x.plot(column='metric_died_count', cmap='OrRd', edgecolor='k', legend=True)
sum(x["metric_died_count"])
# Out:
# myriad_test_agg_25p_v3_0.3_2.txt
# 0
